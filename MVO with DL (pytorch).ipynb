# %%
import os
import json
import random
import numpy as np
import torch
from train.train import Trainer

# %% [markdown]
# ### Fix Seed and Train

# %%
config = json.load(open("config/train_config.json", "r"))

os.environ["PYTHONHASHSEED"] = str(config["SEED"])
random.seed(config["SEED"])
np.random.seed(config["SEED"])
torch.manual_seed(config["SEED"])
torch.cuda.manual_seed(config["SEED"])
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False


worker = Trainer(config)
worker.set_data()
worker.train(visualize=True)
# Out:
# Epoch 1/500
# ----------
# Improved! at 1 epochs, with -0.5546824696498948
# Epoch 2/500
# ----------
# Improved! at 2 epochs, with -0.5555193089955561
# Epoch 3/500
# ----------
# Improved! at 3 epochs, with -0.5564231971228445
# Epoch 4/500
# ----------
# Improved! at 4 epochs, with -0.5574450655966192
# Epoch 5/500
# ----------
# Improved! at 5 epochs, with -0.5586296950240391
# Epoch 6/500
# ----------
# Improved! at 6 epochs, with -0.5601078871939635
# Epoch 7/500
# ----------
# Improved! at 7 epochs, with -0.5620913245790713
# Epoch 8/500
# ----------
# Improved! at 8 epochs, with -0.5650919019370466
# Epoch 9/500
# ----------
# Improved! at 9 epochs, with -0.5706332921981813
# Epoch 10/500
# ----------
# Improved! at 10 epochs, with -0.5747295694576726
# Epoch 11/500
# ----------
# Epoch 12/500
# ----------
# Epoch 13/500
# ----------
# Epoch 14/500
# ----------
# Epoch 15/500
# ----------
# Epoch 16/500
# ----------
# Epoch 17/500
# ----------
# Epoch 18/500
# ----------
# Epoch 19/500
# ----------
# Epoch 20/500
# ----------
# Improved! at 20 epochs, with -0.5768894762606234
# Epoch 21/500
# ----------
# Improved! at 21 epochs, with -0.5803148039692156
# Epoch 22/500
# ----------
# Improved! at 22 epochs, with -0.5844348546218229
# Epoch 23/500
# ----------
# Improved! at 23 epochs, with -0.5863402042839978
# Epoch 24/500
# ----------
# Improved! at 24 epochs, with -0.5866640999510482
# Epoch 25/500
# ----------
# Improved! at 25 epochs, with -0.5873646371670671
# Epoch 26/500
# ----------
# Improved! at 26 epochs, with -0.5875443755774884
# Epoch 27/500
# ----------
# Improved! at 27 epochs, with -0.5914550113516883
# Epoch 28/500
# ----------
# Epoch 29/500
# ----------
# Improved! at 29 epochs, with -0.5926919839269406
# Epoch 30/500
# ----------
# Improved! at 30 epochs, with -0.5960378334731669
# Epoch 31/500
# ----------
# Improved! at 31 epochs, with -0.5990167842120737
# Epoch 32/500
# ----------
# Improved! at 32 epochs, with -0.6012976471636747
# Epoch 33/500
# ----------
# Improved! at 33 epochs, with -0.6033343950638899
# Epoch 34/500
# ----------
# Improved! at 34 epochs, with -0.6077661610938406
# Epoch 35/500
# ----------
# Improved! at 35 epochs, with -0.6079016297652914
# Epoch 36/500
# ----------
# Improved! at 36 epochs, with -0.6105514841305242
# Epoch 37/500
# ----------
# Epoch 38/500
# ----------
# Epoch 39/500
# ----------
# Epoch 40/500
# ----------
# Epoch 41/500
# ----------
# Improved! at 41 epochs, with -0.6105683413711753
# Epoch 42/500
# ----------
# Epoch 43/500
# ----------
# Improved! at 43 epochs, with -0.611337660736329
# Epoch 44/500
# ----------
# Epoch 45/500
# ----------
# Improved! at 45 epochs, with -0.6158581005560386
# Epoch 46/500
# ----------
# Epoch 47/500
# ----------
# Epoch 48/500
# ----------
# Epoch 49/500
# ----------
# Improved! at 49 epochs, with -0.6186286390733878
# Epoch 50/500
# ----------
# Improved! at 50 epochs, with -0.6207561241714538
# Epoch 51/500
# ----------
# Epoch 52/500
# ----------
# Improved! at 52 epochs, with -0.6270464613429598
# Epoch 53/500
# ----------
# Epoch 54/500
# ----------
# Improved! at 54 epochs, with -0.6278228180835373
# Epoch 55/500
# ----------
# Improved! at 55 epochs, with -0.6311200816889068
# Epoch 56/500
# ----------
# Epoch 57/500
# ----------
# Epoch 58/500
# ----------
# Improved! at 58 epochs, with -0.6315285766849646
# Epoch 59/500
# ----------
# Improved! at 59 epochs, with -0.6332293505201468
# Epoch 60/500
# ----------
# Improved! at 60 epochs, with -0.6342691601933659
# Epoch 61/500
# ----------
# Epoch 62/500
# ----------
# Epoch 63/500
# ----------
# Improved! at 63 epochs, with -0.6348188410739641
# Epoch 64/500
# ----------
# Epoch 65/500
# ----------
# Epoch 66/500
# ----------
# Improved! at 66 epochs, with -0.6359952704326527
# Epoch 67/500
# ----------
# Improved! at 67 epochs, with -0.6365792171375172
# Epoch 68/500
# ----------
# Epoch 69/500
# ----------
# Epoch 70/500
# ----------
# Epoch 71/500
# ----------
# Epoch 72/500
# ----------
# Epoch 73/500
# ----------
# Epoch 74/500
# ----------
# Epoch 75/500
# ----------
# Epoch 76/500
# ----------
# Epoch 77/500
# ----------
# Epoch 78/500
# ----------
# Epoch 79/500
# ----------
# Epoch 80/500
# ----------
# Improved! at 80 epochs, with -0.6372607524531917
# Epoch 81/500
# ----------
# Epoch 82/500
# ----------
# Improved! at 82 epochs, with -0.6385514963720297
# Epoch 83/500
# ----------
# Epoch 84/500
# ----------
# Epoch 85/500
# ----------
# Epoch 86/500
# ----------
# Epoch 87/500
# ----------
# Epoch 88/500
# ----------
# Epoch 89/500
# ----------
# Improved! at 89 epochs, with -0.6420930183014353
# Epoch 90/500
# ----------
# Epoch 91/500
# ----------
# Epoch 92/500
# ----------
# Epoch 93/500
# ----------
# Epoch 94/500
# ----------
# Epoch 95/500
# ----------
# Epoch 96/500
# ----------
# Epoch 97/500
# ----------
# Epoch 98/500
# ----------
# Epoch 99/500
# ----------
# Epoch 100/500
# ----------
# Epoch 101/500
# ----------
# Epoch 102/500
# ----------
# Epoch 103/500
# ----------
# Epoch 104/500
# ----------
# Epoch 105/500
# ----------
# Epoch 106/500
# ----------
# Epoch 107/500
# ----------
# Epoch 108/500
# ----------
# Epoch 109/500
# ----------
# Epoch 110/500
# ----------
# Epoch 111/500
# ----------
# Epoch 112/500
# ----------
# Epoch 113/500
# ----------
# Epoch 114/500
# ----------
# Epoch 115/500
# ----------
# Epoch 116/500
# ----------
# Epoch 117/500
# ----------
# Epoch 118/500
# ----------
# Epoch 119/500
# ----------
# (GRU(
#    (gru): GRU(50, 128, batch_first=True)
#    (dropout): Dropout(p=0.3, inplace=False)
#    (fc): Linear(in_features=128, out_features=50, bias=True)
#    (swish): SiLU()
#  ),
#  [-0.2793471110535078,
#   -0.280468196206694,
#   -0.28157649531253964,
#   -0.2829527118853454,
#   -0.284575095833761,
#   -0.28672501319569765,
#   -0.28950594399317087,
#   -0.293517356899021,
#   -0.30144856597200537,
#   -0.32135512271960237,
#   -0.3436415092056166,
#   -0.5728520446935216,
#   -0.5768894762606234,
#   -0.5803148039692156,
#   -0.5844348546218229,
#   -0.5863402042839978,
#   -0.5866640999510482,
#   -0.5873646371670671,
#   -0.5875443755774884,
#   -0.5914550113516883,
#   -0.5894974006994349,
#   -0.5926919839269406,
#   -0.5960378334731669,
#   -0.5990167842120737,
#   -0.6012976471636747,
#   -0.6033343950638899,
#   -0.6077661610938406,
#   -0.6079016297652914,
#   -0.6105514841305242,
#   -0.60850304506115,
#   -0.6093964496174374,
#   -0.6102709365454878,
#   -0.6092777373017493,
#   -0.6105683413711753,
#   -0.6102832404745592,
#   -0.611337660736329,
#   -0.6113142618859136,
#   -0.6158581005560386,
#   -0.6149544068989721,
#   -0.6148569901045915,
#   -0.6132983727934394,
#   -0.6186286390733878,
#   -0.6207561241714538,
#   -0.6206605905616605,
#   -0.6270464613429598,
#   -0.6267269231580399,
#   -0.6278228180835373,
#   -0.6311200816889068,
#   -0.6287813095023504,
#   -0.6304130608568321,
#   -0.6315285766849646,
#   -0.6332293505201468,
#   -0.6342691601933659,
#   -0.6336794574115728,
#   -0.6315094884988425,
#   -0.6348188410739641,
#   -0.6338502897604091,
#   -0.6328704955207334,
#   -0.6359952704326527,
#   -0.6365792171375172,
#   -0.635511656065245,
#   -0.6325243065083348,
#   -0.6315639005923595,
#   -0.6321065288943214,
#   -0.6325120763802851,
#   -0.6331835268317042,
#   -0.6315332051064516,
#   -0.6311495963584732,
#   -0.6315205075048114,
#   -0.6335770526045077,
#   -0.6322094516174213,
#   -0.6339916075403625,
#   -0.6372607524531917,
#   -0.6288569895802317,
#   -0.6385514963720297,
#   -0.6314313722824729,
#   -0.6223055680055877,
#   -0.630728047441792,
#   -0.6292081279931842,
#   -0.6340781389861493,
#   -0.6358726278350162,
#   -0.6420930183014353,
#   -0.6368406717036222,
#   -0.6355649305356518,
#   -0.6302552497064746,
#   -0.6204953018475223,
#   -0.6375084152898273,
#   -0.6338257713092339,
#   -0.6206909623500463,
#   -0.6229510770456211,
#   -0.6302109312366795,
#   -0.621698763322186,
#   -0.6338544248326404,
#   -0.6271488537659516,
#   -0.6060159983667168,
#   -0.6239136944751481,
#   -0.6214246238405639,
#   -0.616420416815861,
#   -0.6196812252337867,
#   -0.6067407590311926,
#   -0.6166888926480268,
#   -0.6076272460254462,
#   -0.6020455640312786,
#   -0.6237896467382843,
#   -0.5784293951819072,
#   -0.6000193883035633,
#   -0.5905524960945586,
#   -0.5804108771923425,
#   -0.5713218335263633,
#   -0.5726332426373217,
#   -0.5862960361347005,
#   -0.5561590589381553])

# %% [markdown]
# ### Backtest

# %%
worker.backtest(visualize=True)
# Out:
# Annualized Return of Portfolio
# EWP_Return      0.170273
# My_Return       0.310951
# Index_Return    0.134716
# dtype: float64
# --------------------
# Annualized Volatility of Portfolio
# EWP_Return      0.158109
# My_Return       0.180532
# Index_Return    0.166945
# dtype: float64
# --------------------
# Annualized Sharp Ratio of Portfolio
# EWP_Return      1.076934
# My_Return       1.722411
# Index_Return    0.806953
# dtype: float64
# --------------------
# MDD
#           EWP MyPortfolio    index_sp
# 0  2020-02-04  2020-02-04  2020-02-04
# 1  2020-04-02  2020-04-02  2020-04-02
# 2    -0.21319   -0.179543   -0.233713
